# %%
import numpy as np
import zdm.analyze_cube as ac
import matplotlib.pyplot as plt
import zdm.analyze_cube as ac

# %%
cube_dir  = "./Cubes/craco_real_cube.npz"

cube=np.load(cube_dir)
ll = ac.get_slice_from_parameters(cube, ["H0"], [74], wanted="ll")
_, vectors, _= ac.get_bayesian_data(ll)
plt.plot(cube["logF"], vectors[-1])

# %%
np.max(ll.flatten())
# Out:
# 0.0

# %%
cube_dir  = "../CRACO/Cubes/craco_full_cube.npz"
cube=np.load(cube_dir)
ll = ac.get_slice_from_parameters(cube, ["H0"], [74], wanted="ll")
_, vectors, _= ac.get_bayesian_data(ll)
plt.plot(cube["logF"], vectors[-1])
